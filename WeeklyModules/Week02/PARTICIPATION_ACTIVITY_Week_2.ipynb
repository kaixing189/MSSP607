# %% [markdown]
# <a href="https://colab.research.google.com/github/kaixing189/MSSP607/blob/main/WeeklyModules/Week02/PARTICIPATION_ACTIVITY_Week_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# @title Default title text

# Cell 1
spam = [2, 4, 6, 8, 10]

# Assign 'hello' as the third value.
spam[2] = 'hello'

print(spam)
# Out:
# [2, 4, 'hello', 8, 10]

# %%
# New cell
letters = ['a', 'b', 'c', 'd']

# b. Evaluate letters[int(int('3'*2)//11)]
result_b = letters[int(int('3'*2)//11)]
print(result_b)

# c. letters[-1] gives the last item because negative indexes count from the end.
result_c = letters[-1]
print(result_c)

# d. letters[:2] gives items from the start up to, but not including, index 2.
result_d = letters[:2]
print(result_d)
# Out:
# d
# d
# ['a', 'b']

# %%
# New cell
my_list = [1, 2, 3]

# Get the tuple form of a list:
my_tuple = tuple(my_list)
print(my_tuple)

# Get a list from a tuple:
back_to_list = list(my_tuple)
print(back_to_list)
# Out:
# (1, 2, 3)
# [1, 2, 3]

# %%
# New cell
def comma_code(items):
    # Convert every item to a string so the function works with any list.
    items = [str(item) for item in items]

    if len(items) == 0:
        return ''
    elif len(items) == 1:
        return items[0]
    elif len(items) == 2:
        return f'{items[0]} and {items[1]}'
    else:
        return ', '.join(items[:-1]) + ', and ' + items[-1]

spam = ['apples', 'bananas', 'tofu', 'cats']
print(comma_code(spam))
# Out:
# apples, bananas, tofu, and cats
